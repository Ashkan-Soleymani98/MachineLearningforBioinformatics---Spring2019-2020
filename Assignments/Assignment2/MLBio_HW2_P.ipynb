# %% [markdown]
# # Machine Learning in Bioinformatics

# %% [markdown]
# # Homework 2:
#  !!! If you don't fill these fields, your homework does not count !!!<by/>
#  #### first name and last name :
#  #### student number :

# %% [markdown]
# You can run cells by hitting `Shift` + `Enter` or `ctrl` + `Enter`. <br/>
# We highly recommend you to read each line of code carefully and try to understand what it exactly does. <br/>
# Just alter the parts that is between green comments and specified for you. Please do not change other parts.

# %%
# importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# %% [markdown]
# # Problem 1. soft margin SVM
# ### about the Data:<br/>
# The purpose of this project is to classify tumors into malignant or benign. The following dataset is constructed based on images of tumors. Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.
# For more details about the features of this dataset you can visit this link:
# https://scikit-learn.org/stable/datasets/index.html#breast-cancer-dataset<br/>
# This dataset contains 30 features and 1 label that is called target. We should find a proper hyperplane that separates malignant and benign samples.
# The original dataset labels is 0 and 1 and in the following code boxes we change it to -1 and 1.

# %%
cancer = load_breast_cancer()
df = pd.DataFrame(np.c_[cancer["data"], cancer["target"]], columns = np.append(cancer["feature_names"],["target"]))
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890     0.0
# 1          0.2750                  0.08902     0.0
# 2          0.3613                  0.08758     0.0
# 3          0.6638                  0.17300     0.0
# 4          0.2364                  0.07678     0.0
#
# [5 rows x 31 columns]

# %%
cancer.target = np.where(cancer.target==0, -1, cancer.target) 
X_train ,X_test ,X_val ,y_train ,y_test ,y_val = None ,None ,None ,None ,None ,None
################################################################################
# TODO: using train_test_split package, split your data into 3 numpy array     #
# called X_train, X_test, and X_val and also split the corresponding labels as #
# y_train, y_test, and y_val. After spliting, the ratio of your data should be # 
# approximately like this:                                                     #
#  Train : 72%     test : 20%       validation : 8%                            #
################################################################################

#write your code here
X, Y = cancer["data"], cancer["target"]
X_train_validation, X_test, y_train_validation, y_test = train_test_split(X, Y, shuffle=True, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train_validation, y_train_validation, test_size=0.1)

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
print((X_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_val.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_val.shape[0]/cancer.data.shape[0]) * 100, "%")
# Out:
# 71.8804920913884 %
# 71.8804920913884 %
# 20.035149384885763 %
# 20.035149384885763 %
# 8.084358523725834 %
# 8.084358523725834 %

# %% [markdown]
# ### soft margin SVM optimization:<br/>
# We add 1 at the beginning of each Xs data (X_train, X_val , ...) and then the bias will be calculated implicitly.
# Then you should minimize the following SVM loss function (using gradient descent) with changing parameters of model.<br>
# In this notation:
# \begin{equation}
# x_i , y_i
# \end{equation}
# refers to feature vector of the sample and the label of our training data<br>
# and this is SVM loss function:
#
# \begin{equation}
# \large
# J(W) = \frac{1}{N} \sum_{i=1}^{N}{L^{(i)}} + \frac{\lambda}{2} ||W||^2\\
# \large
# L^{(i)} ={max(0, 1 - y_i(w^{T}x_i)})
# \;\\
# \end{equation}

# %%
# >>>>>WARNING: RUN THIS CELL ONLY ONCE!<<<<<

# adding 1s to the end of feature vectors to be multiplied by bias term of weights
X_val = np.insert(X_val, 0, 1, axis=1)
X_train = np.insert(X_train, 0, 1, axis=1)
X_test = np.insert(X_test, 0, 1, axis=1)
print(X_train.shape)  
print(X_val.shape)  
print(X_test.shape)
# Out:
# (409, 31)
# (46, 31)
# (114, 31)

# %% [markdown]
# Complete the following functions in SVM class. In the part that you should compute loss function of this class, you are not allowed to use "for" loop.

# %%
class SVM:
    def __init__(self, n_features: int, std: float):
        """
        n_features: number of features in (or the dimension of) each instance
        std: standard deviation used in the initialization of the weights of svm
        """
        self.n_features = n_features
        ################################################################################
        # TODO: Initialize the weights of svm using random normal distribution with    #
        # standard deviation equals to std.                                            #
        ################################################################################

        #write your code here
        self.weights = np.random.normal(0, std, n_features)

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):
        """
        X: training instances as a 2d-array with shape (num_train, n_features)
        y: labels corresponsing to the given training instances as a 1d-array with shape (num_train,)
        reg_coeff: L2-regularization coefficient
        """
        loss = 0.0
        
        #################################################################################
        # TODO: Compute the hinge loss specified in the notebook and save it in the loss#                                                   # loss variable.                                                               #
        # NOTE: YOU ARE NOT ALLOWED TO USE FOR LOOPS!                                   #
        # Don't forget L2-regularization term in your implementation!                   #
        #################################################################################
        
        #write your code
        N = len(X)
        loss += np.sum(np.maximum(0, 1 - y * np.matmul(X, self.weights))) / N + (reg_coeff / 2) * (np.linalg.norm(self.weights, ord=2) ** 2) 
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return loss
        
    def update_weights(self,  X: np.ndarray, y: np.ndarray, learning_rate: float , reg_coeff: float):
        """
        Updates the weights of the svm using the gradient of computed loss with respect to the weights. 
        learning_rate: learning rate that will be used in gradient descent to update the weights
        """
        ################################################################################
        # TODO: Compute the gradient of loss computed above w.r.t the svm weights.     #
        # and then update self.w with the computed gradient.                           #
        # (don't forget learning rate and reg_coeff in update rule)                    #
        # Don't forget L2-regularization term in your implementation!                  #
        ################################################################################
        
        #write your code here
        def convert_positives_to_ones(vector: np.ndarray):
            return np.floor((np.sign(vector) + 1) / 2)
        
        N = len(X)
        gradient = -sum((X.T * (y * convert_positives_to_ones(1 - np.matmul(X, self.weights) * y))).T) / N + reg_coeff * self.weights
        self.weights -= learning_rate * gradient
        
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
    def predict(self, X):
        """
        X: Numpy 2d-array of instances
        """
        y_pred = None
        ################################################################################
        # TODO: predict the labels for the instances in X and save them in y_pred.     #                                      #
        ################################################################################

        #write your code here
        y_pred = [1 if np.dot(X[i], self.weights) >= 0 else -1 for i in range(len(X))]
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return y_pred

# %% [markdown]
# This cell contains your hyper parameters:

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8

# %% [markdown]
# In this cell using your SVM class, we want to train our model for cancer data:<br/>
# In every iteration you should see your training loss decrease.

# %%
from sklearn.metrics import accuracy_score
model = SVM(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 1.016951, val acc 60.87%
# iteration 100, loss 0.964620, val acc 39.13%
# iteration 200, loss 0.924257, val acc 39.13%
# iteration 300, loss 0.913547, val acc 39.13%
# iteration 400, loss 0.911283, val acc 39.13%
# iteration 500, loss 0.909797, val acc 39.13%
# iteration 600, loss 0.908378, val acc 39.13%
# iteration 700, loss 0.906959, val acc 39.13%
# iteration 800, loss 0.905542, val acc 39.13%
# iteration 900, loss 0.904136, val acc 39.13%
# iteration 1000, loss 0.902735, val acc 39.13%
# iteration 1100, loss 0.901334, val acc 39.13%
# iteration 1200, loss 0.899974, val acc 39.13%
# iteration 1300, loss 0.898616, val acc 39.13%
# iteration 1400, loss 0.897260, val acc 39.13%
# iteration 1500, loss 0.895907, val acc 39.13%
# iteration 1600, loss 0.894557, val acc 39.13%
# iteration 1700, loss 0.893207, val acc 39.13%
# iteration 1800, loss 0.891858, val acc 39.13%
# iteration 1900, loss 0.890508, val acc 39.13%
# iteration 2000, loss 0.889159, val acc 39.13%
# iteration 2100, loss 0.887809, val acc 39.13%
# iteration 2200, loss 0.886460, val acc 39.13%
# iteration 2300, loss 0.885111, val acc 39.13%
# iteration 2400, loss 0.883767, val acc 39.13%
# iteration 2500, loss 0.882440, val acc 39.13%
# iteration 2600, loss 0.881112, val acc 39.13%
# iteration 2700, loss 0.879788, val acc 39.13%
# iteration 2800, loss 0.878480, val acc 39.13%
# iteration 2900, loss 0.877181, val acc 39.13%
# iteration 3000, loss 0.875914, val acc 39.13%
# iteration 3100, loss 0.874647, val acc 39.13%
# iteration 3200, loss 0.873380, val acc 39.13%
# iteration 3300, loss 0.872113, val acc 39.13%
# iteration 3400, loss 0.870848, val acc 39.13%
# iteration 3500, loss 0.869595, val acc 39.13%
# iteration 3600, loss 0.868391, val acc 39.13%
# iteration 3700, loss 0.867194, val acc 39.13%
# iteration 3800, loss 0.866008, val acc 39.13%
# iteration 3900, loss 0.864822, val acc 39.13%
# iteration 4000, loss 0.863636, val acc 39.13%
# iteration 4100, loss 0.862450, val acc 39.13%
# iteration 4200, loss 0.861264, val acc 39.13%
# iteration 4300, loss 0.860078, val acc 39.13%
# iteration 4400, loss 0.858892, val acc 39.13%
# iteration 4500, loss 0.857706, val acc 39.13%
# iteration 4600, loss 0.856521, val acc 39.13%
# iteration 4700, loss 0.855335, val acc 39.13%
# iteration 4800, loss 0.854149, val acc 39.13%
# iteration 4900, loss 0.852964, val acc 39.13%
# iteration 5000, loss 0.851778, val acc 39.13%
# iteration 5100, loss 0.850593, val acc 39.13%
# iteration 5200, loss 0.849417, val acc 39.13%
# iteration 5300, loss 0.848244, val acc 39.13%
# iteration 5400, loss 0.847070, val acc 39.13%
# iteration 5500, loss 0.845897, val acc 39.13%
# iteration 5600, loss 0.844724, val acc 39.13%
# iteration 5700, loss 0.843552, val acc 39.13%
# iteration 5800, loss 0.842381, val acc 39.13%
# iteration 5900, loss 0.841209, val acc 39.13%
# iteration 6000, loss 0.840037, val acc 39.13%
# iteration 12000, loss 0.770751, val acc 86.96%
# iteration 12100, loss 0.769610, val acc 86.96%
# iteration 12200, loss 0.768469, val acc 86.96%
# iteration 12300, loss 0.767328, val acc 86.96%
# iteration 12400, loss 0.766187, val acc 86.96%
# iteration 12500, loss 0.765046, val acc 86.96%
# iteration 12600, loss 0.763905, val acc 86.96%
# iteration 12700, loss 0.762764, val acc 86.96%
# iteration 12800, loss 0.761626, val acc 86.96%
# iteration 12900, loss 0.760497, val acc 91.30%
# iteration 13000, loss 0.759369, val acc 91.30%
# iteration 13100, loss 0.758240, val acc 91.30%
# iteration 13200, loss 0.757112, val acc 91.30%
# iteration 13300, loss 0.755983, val acc 91.30%
# iteration 13400, loss 0.754855, val acc 91.30%
# iteration 13500, loss 0.753726, val acc 91.30%
# iteration 13600, loss 0.752598, val acc 91.30%
# iteration 13700, loss 0.751470, val acc 91.30%
# iteration 13800, loss 0.750343, val acc 93.48%
# iteration 13900, loss 0.749216, val acc 93.48%
# iteration 14000, loss 0.748088, val acc 91.30%
# iteration 14100, loss 0.746961, val acc 91.30%
# iteration 14200, loss 0.745834, val acc 91.30%
# iteration 14300, loss 0.744706, val acc 91.30%
# iteration 14400, loss 0.743579, val acc 91.30%
# iteration 14500, loss 0.742452, val acc 91.30%
# iteration 14600, loss 0.741325, val acc 91.30%
# iteration 14700, loss 0.740198, val acc 91.30%
# iteration 14800, loss 0.739071, val acc 91.30%
# iteration 14900, loss 0.737944, val acc 91.30%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #
# using loss_loss_history and loss_val_history                                     #
####################################################################################

#write your code here
plt.plot([i for i in range(num_iters)], loss_history, label="Train")
plt.plot([i for i in range(num_iters)], loss_val_history, label="Validation")
plt.legend(loc="upper right")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 1:
# With changing your hyper parameters, find a configuration of hyper parameters that cause your loss to increase after each iteration and then report that configuration in the next cell. Explain why our loss increases?
# Write your answer in "Loss increases in some iterations since learning rate is so high that instead of approaching the optimum point, the classifier fluctuates around it! Moreover regularization term is so high that makes the optimizer only try to diminish the value of wights instead of decreasing the loss.""

# %% [markdown]
# std = "0.0001" <br>
# num_iters = "15000"<br>
# reg_coeff = "10000"<br>
# learning_rate = "1e-5"<br>

# %% [markdown]
# ### Question 2:
# In this cell please explain the reason of this event<br>
# Answer:

# %%
val_preds =  model.predict(X_test)
###########################################################################################
# TODO: find the Confusion Matrix between val_preds and real labels (y_test) for test data#
# then report the accuracy of the model.                                                  #
# you are not allowed to use any premade function for accuracy and confusion matrix       #
###########################################################################################

#write your code here
def get_confusion_matrix(Y_test, Y_pred):
    TP, FP, TN, FN = 0, 0, 0, 0
    for i, j in zip(Y_test, Y_pred):
        if i == 1 and j == 1:
            TP += 1
        elif i == 1 and j == -1:
            FN += 1
        elif i == -1 and j == 1:
            FP += 1
        elif i == -1 and j == -1:
            TN += 1
    return {"T (+1)": TP, "F (+1)": FP, "T (-1)": TN, "F (-1)": FN}

def get_accuracy(Y_test, Y_pred):
    conf_matrix = get_confusion_matrix(Y_test, Y_pred)
    return (conf_matrix["T (+1)"] + conf_matrix["T (-1)"]) / (conf_matrix["T (+1)"] + conf_matrix["T (-1)"] + conf_matrix["F (+1)"] + conf_matrix["F (-1)"])

print(get_confusion_matrix(y_test, val_preds))
print(get_accuracy(y_test, val_preds))
###########################################################################################
#                                END OF YOUR EXPLANATION                                  #
###########################################################################################
# Out:
# {'T (+1)': 73, 'F (+1)': 0, 'T (-1)': 38, 'F (-1)': 3}
# 0.9736842105263158

# %% [markdown]
# In the next part, we sample from training data with certain size (batch size) instead of using all the training data in each iteration, and train our model on batch data:

# %%
std = 0.0001
batch_size = 200
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8
model = SVM(n_features=X_train.shape[1], std= std )

# %%
loss_history = []
loss_val_history = []
for it in range(num_iters):
    X_batch = None
    y_batch = None
    ################################################################################
    # TODO: Sample batch_size elements from the training data and their            #
    # corresponding labels to use in this round of gradient descent.               #
    # Store the data in X_batch and their corresponding labels in                  #
    # y_batch; after sampling X_batch should have shape (batch_size, n_features)   #
    # and y_batch should have shape (batch_size,)                                  #
    #                                                                              #
    # Hint: Use np.random.choice to generate indices. Sampling with                #
    # replacement is faster than sampling without replacement.                     #
    ################################################################################

    #write your code here
    index = np.random.choice([i for i in range(len(X_train))], batch_size)
    X_batch = X_train[index]
    y_batch = y_train[index]

    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################
    loss = model.loss(X_batch, y_batch, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_batch, y_batch, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 1.022264, val acc 60.87%
# iteration 100, loss 0.973134, val acc 39.13%
# iteration 200, loss 0.902615, val acc 39.13%
# iteration 300, loss 0.995201, val acc 39.13%
# iteration 400, loss 0.894336, val acc 39.13%
# iteration 500, loss 0.945019, val acc 39.13%
# iteration 600, loss 0.899807, val acc 39.13%
# iteration 700, loss 0.936381, val acc 39.13%
# iteration 800, loss 0.920490, val acc 39.13%
# iteration 900, loss 0.895418, val acc 39.13%
# iteration 1000, loss 0.941922, val acc 39.13%
# iteration 1100, loss 0.886576, val acc 39.13%
# iteration 1200, loss 0.933102, val acc 39.13%
# iteration 1300, loss 0.877618, val acc 39.13%
# iteration 1400, loss 0.828228, val acc 39.13%
# iteration 1500, loss 0.881254, val acc 39.13%
# iteration 1600, loss 0.963842, val acc 39.13%
# iteration 1700, loss 0.950279, val acc 39.13%
# iteration 1800, loss 0.872346, val acc 39.13%
# iteration 1900, loss 0.921073, val acc 39.13%
# iteration 2000, loss 0.890045, val acc 39.13%
# iteration 2100, loss 0.894434, val acc 39.13%
# iteration 2200, loss 0.864350, val acc 39.13%
# iteration 2300, loss 0.907998, val acc 39.13%
# iteration 2400, loss 0.819934, val acc 39.13%
# iteration 2500, loss 0.891404, val acc 39.13%
# iteration 2600, loss 0.830885, val acc 39.13%
# iteration 2700, loss 0.877583, val acc 39.13%
# iteration 2800, loss 0.944194, val acc 39.13%
# iteration 2900, loss 0.882452, val acc 39.13%
# iteration 3000, loss 0.814190, val acc 39.13%
# iteration 3100, loss 0.854805, val acc 39.13%
# iteration 3200, loss 0.912056, val acc 39.13%
# iteration 3300, loss 0.890957, val acc 39.13%
# iteration 3400, loss 0.877550, val acc 39.13%
# iteration 3500, loss 0.913704, val acc 39.13%
# iteration 3600, loss 0.884159, val acc 39.13%
# iteration 3700, loss 0.861418, val acc 39.13%
# iteration 3800, loss 0.845588, val acc 39.13%
# iteration 3900, loss 0.775266, val acc 39.13%
# iteration 4000, loss 0.892485, val acc 39.13%
# iteration 4100, loss 0.851345, val acc 39.13%
# iteration 4200, loss 0.910088, val acc 39.13%
# iteration 4300, loss 0.895206, val acc 39.13%
# iteration 4400, loss 0.869721, val acc 39.13%
# iteration 4500, loss 0.858986, val acc 39.13%
# iteration 4600, loss 0.845263, val acc 39.13%
# iteration 4700, loss 0.872744, val acc 39.13%
# iteration 4800, loss 0.874554, val acc 39.13%
# iteration 4900, loss 0.854209, val acc 39.13%
# iteration 5000, loss 0.866137, val acc 39.13%
# iteration 5100, loss 0.853867, val acc 39.13%
# iteration 5200, loss 0.823055, val acc 39.13%
# iteration 5300, loss 0.825265, val acc 39.13%
# iteration 5400, loss 0.889678, val acc 39.13%
# iteration 5500, loss 0.842112, val acc 39.13%
# iteration 5600, loss 0.811631, val acc 39.13%
# iteration 5700, loss 0.858871, val acc 39.13%
# iteration 5800, loss 0.882559, val acc 39.13%
# iteration 5900, loss 0.887893, val acc 39.13%
# iteration 6000, loss 0.805125, val acc 39.13%
# iteration 6100, loss 0.866660, val acc 39.13%
# iteration 6200, loss 0.809304, val acc 39.13%
# iteration 6300, loss 0.829862, val acc 39.13%
# iteration 6400, loss 0.896163, val acc 39.13%
# iteration 6500, loss 0.857164, val acc 39.13%
# iteration 6600, loss 0.783187, val acc 39.13%
# iteration 6700, loss 0.873205, val acc 39.13%
# iteration 6800, loss 0.840245, val acc 39.13%
# iteration 6900, loss 0.823245, val acc 39.13%
# iteration 7000, loss 0.837440, val acc 39.13%
# iteration 7100, loss 0.862508, val acc 39.13%
# iteration 7200, loss 0.852561, val acc 39.13%
# iteration 7300, loss 0.828692, val acc 41.30%
# iteration 7400, loss 0.834218, val acc 41.30%
# iteration 7500, loss 0.835037, val acc 41.30%
# iteration 7600, loss 0.791704, val acc 45.65%
# iteration 7700, loss 0.810542, val acc 45.65%
# iteration 7800, loss 0.858814, val acc 45.65%
# iteration 7900, loss 0.833581, val acc 45.65%
# iteration 8000, loss 0.816599, val acc 45.65%
# iteration 8100, loss 0.788127, val acc 45.65%
# iteration 8200, loss 0.833094, val acc 47.83%
# iteration 8300, loss 0.780963, val acc 47.83%
# iteration 8400, loss 0.829568, val acc 47.83%
# iteration 8500, loss 0.810065, val acc 52.17%
# iteration 14500, loss 0.765919, val acc 91.30%
# iteration 14600, loss 0.756555, val acc 91.30%
# iteration 14700, loss 0.753775, val acc 91.30%
# iteration 14800, loss 0.741881, val acc 91.30%
# iteration 14900, loss 0.765303, val acc 91.30%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #

####################################################################################

#write your code here
plt.plot([i for i in range(num_iters)], loss_history, label="Train")
plt.plot([i for i in range(num_iters)], loss_val_history, label="Validation")
plt.legend(loc="upper right")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 3:
# Explain why we see fluctuation in this plot?<br>
# Answer: As loss in this case not only a function of optimization process but also it depends on random batch sampling itself too. Since the gradient in the whole training data is being approximated using only a random batch in each step.

# %% [markdown]
# # Problem 2. Perceptron

# %% [markdown]
# By now, you should know how to use and how to implement SVM from scratch.
# In fact, for perceptron we can use premade functions as below:

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
val_preds = clf.predict(X_test)
print(confusion_matrix(y_test,val_preds,[1,-1]))
print('test acc %.2f%%' % (accuracy_score(y_test,val_preds) * 100))

# %% [markdown]
# ### Question 4:
# It is time for you to write your own code instead of completing some parts of a premade code.<br>
# So you can not use any premade functions like the previous cell.
# Write your code in the end of this .ipynb file <br>
# You should make your model and use that to build these outputs:<br>
# 1- Report loss of training and accuracy of validation data on each epoch of training process.<br>
# 2- You are allowed to use any normalization approach if need be.<br>
# 3- Plot your training and validation loss vs number of iterations in one plot.<br>
# 4- Finally print your confusion matrix and accuracy for your testing set.<br>
# With changing your hyperparameters try to get a good and reasonable accuracy and confusion matrix on testing set (similar to the accuracy when we used the package).

# %%
class Perceptron:
    def __init__(self, n_features: int, std: float):
        self.n_features = n_features
        self.weights = np.random.normal(0, std, self.n_features)

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):
        loss = np.sum((-1 * np.matmul(X, self.weights) * y)[np.where((np.matmul(X, self.weights) * y) < 0)]) / len(X) + (reg_coeff / 2) * (np.linalg.norm(self.weights, ord=2) ** 2) 
        return loss

    def update_weights(self, X: np.ndarray, y: np.ndarray, learning_rate: float, reg_coeff: float):
        gradient = ((-1 * np.sum(((X.T * y).T)[np.where((-1 * np.matmul(X, self.weights) * y) > 0)], axis=0)) / len(X)) + reg_coeff * self.weights
        self.weights -= learning_rate * gradient

    def predict(self, X):
        y_pred = [1 if np.dot(X[i], self.weights) >= 0 else -1 for i in range(len(X))]
        return y_pred

# %%
std = 0.0001
num_iters = 10000
reg_coeff = 20
learning_rate=1e-9

# %%
model = Perceptron(n_features=X_train.shape[1], std= std)
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 6300, loss 0.000638, val acc 76.09%
# iteration 6400, loss 0.000628, val acc 76.09%
# iteration 6500, loss 0.000618, val acc 78.26%
# iteration 6600, loss 0.000608, val acc 78.26%
# iteration 6700, loss 0.000598, val acc 78.26%
# iteration 6800, loss 0.000588, val acc 78.26%
# iteration 6900, loss 0.000578, val acc 78.26%
# iteration 7000, loss 0.000569, val acc 78.26%
# iteration 7100, loss 0.000559, val acc 78.26%
# iteration 7200, loss 0.000550, val acc 78.26%
# iteration 7300, loss 0.000542, val acc 76.09%
# iteration 7400, loss 0.000534, val acc 76.09%
# iteration 7500, loss 0.000527, val acc 76.09%
# iteration 7600, loss 0.000520, val acc 76.09%
# iteration 7700, loss 0.000513, val acc 76.09%
# iteration 7800, loss 0.000507, val acc 78.26%
# iteration 7900, loss 0.000500, val acc 78.26%
# iteration 8000, loss 0.000494, val acc 78.26%
# iteration 8100, loss 0.000488, val acc 78.26%
# iteration 8200, loss 0.000482, val acc 78.26%
# iteration 8300, loss 0.000476, val acc 80.43%
# iteration 8400, loss 0.000470, val acc 80.43%
# iteration 8500, loss 0.000464, val acc 80.43%
# iteration 8600, loss 0.000459, val acc 80.43%
# iteration 8700, loss 0.000453, val acc 80.43%
# iteration 8800, loss 0.000448, val acc 80.43%
# iteration 8900, loss 0.000443, val acc 82.61%
# iteration 9000, loss 0.000437, val acc 82.61%
# iteration 9100, loss 0.000432, val acc 82.61%
# iteration 9200, loss 0.000427, val acc 82.61%
# iteration 9300, loss 0.000422, val acc 82.61%
# iteration 9400, loss 0.000417, val acc 82.61%
# iteration 9500, loss 0.000411, val acc 82.61%
# iteration 9600, loss 0.000406, val acc 82.61%
# iteration 9700, loss 0.000401, val acc 82.61%
# iteration 9800, loss 0.000396, val acc 82.61%
# iteration 9900, loss 0.000391, val acc 82.61%

# %%
plt.plot([i for i in range(num_iters)], loss_history, label="Train")
plt.plot([i for i in range(num_iters)], loss_val_history, label="Validation")
plt.legend(loc="upper right")
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
val_preds =  model.predict(X_test)

def get_confusion_matrix(Y_test, Y_pred):
    TP, FP, TN, FN = 0, 0, 0, 0
    for i, j in zip(Y_test, Y_pred):
        if i == 1 and j == 1:
            TP += 1
        elif i == 1 and j == -1:
            FN += 1
        elif i == -1 and j == 1:
            FP += 1
        elif i == -1 and j == -1:
            TN += 1
    return {"T (+1)": TP, "F (+1)": FP, "T (-1)": TN, "F (-1)": FN}

def get_accuracy(Y_test, Y_pred):
    conf_matrix = get_confusion_matrix(Y_test, Y_pred)
    return (conf_matrix["T (+1)"] + conf_matrix["T (-1)"]) / (conf_matrix["T (+1)"] + conf_matrix["T (-1)"] + conf_matrix["F (+1)"] + conf_matrix["F (-1)"])

print(get_confusion_matrix(y_test, val_preds))
print(get_accuracy(y_test, val_preds))
# Out:
# {'T (+1)': 58, 'F (+1)': 7, 'T (-1)': 31, 'F (-1)': 18}
# 0.7807017543859649
